# %% [markdown]
# ## Połączenie z bazą danych przy pomocy psycopg2 i pandas oraz dołączenie modułu main

# %%
import main

import numpy as np
import pickle
import psycopg2 as pg
import pandas.io.sql as psql
import pandas as pd

# %% [markdown]
# ## Zadania wprowadzające
# Wykonaj zapytania przy użyciu DBMS.

# %% [markdown]
# ***1. Znajdź liczbę wszystkich filmów o tej samej długości.***

# %%
sql = '''SELECT
             length, COUNT(title) number_of_films
         FROM
             film
         GROUP BY
             length;'''

pd.read_sql(sql, con=main.connection)
# Out:
#      length  number_of_films
# 0       129                7
# 1       106                6
# 2       120                9
# 3       171                8
# 4       138                6
# ..      ...              ...
# 135     159                6
# 136      72                4
# 137     177                6
# 138     141                7
# 139     144                8
#
# [140 rows x 2 columns]

# %% [markdown]
# ***2. Znajdź wszystkich klientów mieszkających w tym samym mieście.***

# %%
sql = f'''SELECT
              city.city, STRING_AGG(CONCAT(customer.first_name, ' ', customer.last_name), ', '
                                      ORDER BY customer.last_name) AS customers, COUNT(customer.first_name) number_of_customers
          FROM
              city
          INNER JOIN address ON city.city_id=address.city_id
          INNER JOIN customer ON address.address_id=customer.address_id
          GROUP BY
              city.city;'''

pd.read_sql(sql, con=main.connection)
# Out:
#                    city        customers  number_of_customers
# 0    A Corua (La Corua)    Julie Sanchez                    1
# 1                  Abha      Peggy Myers                    1
# 2             Abu Dhabi       Tom Milner                    1
# 3                  Acua     Glen Talbert                    1
# 4                 Adana   Larry Thrasher                    1
# ..                  ...              ...                  ...
# 592               Zaria   Constance Reid                    1
# 593        Zeleznogorsk       Jack Foust                    1
# 594         Zhezqazghan        Byron Box                    1
# 595            Zhoushan     Guy Brownlee                    1
# 596          Ziguinchor  Ronnie Ricketts                    1
#
# [597 rows x 3 columns]

# %% [markdown]
# ***3. Oblicz średni koszt wypożyczenia wszystkich filmów.***

# %%
sql = '''SELECT
             AVG(amount) average_payment
         FROM
             payment;'''

pd.read_sql(sql, con=main.connection)
# Out:
#    average_payment
# 0         4.200606

# %% [markdown]
# ***4. Oblicz i wyświetl liczbę filmów we wszystkich kategoriach.***

# %%
sql = '''SELECT
             category.name, COUNT(film.title) number_of_films
         FROM
             category
         INNER JOIN film_category ON category.category_id=film_category.category_id
         INNER JOIN film ON film.film_id=film_category.film_id
         GROUP BY
             category.name
         ORDER BY
             category.name;'''

pd.read_sql(sql, con=main.connection)
# Out:
#            name  number_of_films
# 0        Action               64
# 1     Animation               66
# 2      Children               60
# 3      Classics               57
# 4        Comedy               58
# 5   Documentary               68
# 6         Drama               62
# 7        Family               69
# 8       Foreign               73
# 9         Games               61
# 10       Horror               56
# 11        Music               51
# 12          New               63
# 13       Sci-Fi               61
# 14       Sports               74
# 15       Travel               57

# %% [markdown]
# ***5. Wyświetl liczbę wszystkich klientów pogrupowanych według kraju.***

# %%
sql = '''SELECT
             country.country, STRING_AGG(CONCAT(customer.first_name, ' ', customer.last_name), ', '
                                      ORDER BY customer.last_name) AS customers, COUNT(customer.first_name) number_of_customers
         FROM
             customer
         INNER JOIN address ON customer.address_id=address.address_id
         INNER JOIN city ON address.city_id=city.city_id
         INNER JOIN country ON country.country_id=city.country_id
         GROUP BY
             country.country
         ORDER BY
             country.country;'''

pd.read_sql(sql, con=main.connection)
# Out:
#                   country                                          customers  \
# 0             Afghanistan                                         Vera Mccoy
# 1                 Algeria            June Carroll, Mario Cheatham, Judy Gray
# 2          American Samoa                                     Anthony Schwab
# 3                  Angola                        Martin Bales, Claude Herzog
# 4                Anguilla                                     Bobby Boudreau
# ..                    ...                                                ...
# 103               Vietnam  Beth Franklin, Harvey Guajardo, Patrick Newsom...
# 104  Virgin Islands, U.S.                                      Nathan Runyon
# 105                 Yemen  Gordon Allard, Ella Oliver, William Satterfiel...
# 106            Yugoslavia                             Maria Miller, Max Pitt
# 107                Zambia                                     Barry Lovelace
#
#      number_of_customers
# 0                      1
# 1                      3
# 2                      1
# 3                      2
# 4                      1
# ..                   ...
# 103                    6
# 104                    1
# 105                    4
# 106                    2
# 107                    1
#
# [108 rows x 3 columns]

# %% [markdown]
# ***6. Wyświetl informacje o sklepie, który ma więcej niż 100 klientów i mniej niż 300 klientów.***

# %%
sql = '''SELECT address.address, store.count number_of_customers
         FROM (
         SELECT
             store.address_id, COUNT(customer.customer_id)
         FROM
             customer
         INNER JOIN store ON customer.store_id=store.store_id
         GROUP BY
             store.store_id
         HAVING COUNT(customer.customer_id) BETWEEN 101
         AND 299) AS store
         INNER JOIN address ON store.address_id=address.address_id;'''

pd.read_sql(sql, con=main.connection)
# Out:
#               address  number_of_customers
# 0  28 MySQL Boulevard                  273

# %% [markdown]
# ***7. Wybierz wszystkich klientów, którzy oglądali filmy ponad 200 godzin.***

# %%
sql = '''SELECT
             customer.first_name, customer.last_name, SUM(film.length) total_film_length
         FROM
             customer
         INNER JOIN rental ON customer.customer_id=rental.customer_id
         INNER JOIN inventory ON rental.inventory_id=inventory.inventory_id
         INNER JOIN film ON inventory.film_id=film.film_id
         GROUP BY
             customer.customer_id
         HAVING
             SUM(film.length) > 200 * 60;'''

pd.read_sql(sql, con=main.connection)
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, total_film_length]
# Index: []

# %% [markdown]
# Długość filmu jest podawana w minutach.
# Nikt nie oglądał filmów ponad 200 godzin.

# %% [markdown]
# ***8. Oblicz średnią wartość wypożyczenia filmu.***

# %%
sql = '''SELECT
             AVG(amount)
         FROM
             payment;'''

pd.read_sql(sql, con=main.connection)
# Out:
#         avg
# 0  4.200606

# %% [markdown]
# Zadanie tożsame z zadaniem 3.

# %% [markdown]
# ***9. Oblicz średnią wartość długości filmu we wszystkich kategoriach.***

# %%
sql = f'''SELECT
              category.name, AVG(film.length) average_film_length
          FROM
              category
          INNER JOIN film_category ON category.category_id=film_category.category_id
          INNER JOIN film ON film_category.film_id=film.film_id
          GROUP BY
              category.name;'''

pd.read_sql(sql, con=main.connection)
# Out:
#            name  average_film_length
# 0        Horror           112.482143
# 1        Comedy           115.827586
# 2        Sci-Fi           108.196721
# 3         Drama           120.838710
# 4       Foreign           121.698630
# 5      Classics           111.666667
# 6         Games           127.836066
# 7           New           111.126984
# 8        Travel           113.315789
# 9         Music           113.647059
# 10       Action           111.609375
# 11  Documentary           108.750000
# 12       Sports           128.202703
# 13    Animation           111.015152
# 14       Family           114.782609
# 15     Children           109.800000

# %% [markdown]
# Długość filmu jest podawana w minutach.

# %% [markdown]
# ***10. Znajdź najdłuższe tytuły filmowe we wszystkich kategoriach.***

# %%
sql = f'''SELECT
              name, STRING_AGG(title, ', ') AS titles, title_length
          FROM (
              SELECT
                  f.name, f.title, c.max title_length
              FROM (
                  SELECT
                      category.name, film.title
                  FROM
                      category
                  INNER JOIN film_category ON category.category_id=film_category.category_id
                  INNER JOIN film ON film_category.film_id=film.film_id) AS f
              INNER JOIN (
                  SELECT
                      category.name, MAX(LENGTH(film.title))
                  FROM
                      category
                  INNER JOIN film_category ON category.category_id=film_category.category_id
                  INNER JOIN film ON film_category.film_id=film.film_id
                  GROUP BY
                      category.name) AS c ON f.name=c.name AND LENGTH(f.title)=c.max) AS _
          GROUP BY
              name, title_length;'''

pd.read_sql(sql, con=main.connection)
# Out:
#            name                                             titles  \
# 0        Action                            Entrapment Satisfaction
# 1     Animation                             Telemark Heartbreakers
# 2      Children  Heartbreakers Bright, Microcosmos Paradise, Sw...
# 3      Classics                            Extraordinary Conquerer
# 4        Comedy                            Trainspotting Strangers
# 5   Documentary     Intolerable Intentions, Deliverance Mulholland
# 6         Drama                             Goldfinger Sensibility
# 7        Family                             Resurrection Silverado
# 8       Foreign  Reservoir Adaptation, Impossible Prejudice, Ba...
# 9         Games       Creatures Shakespeare, Bulworth Commandments
# 10       Horror                        Arachnophobia Rollercoaster
# 11        Music                             Confidential Interview
# 12          New                              Flamingos Connecticut
# 13       Sci-Fi  Cincinatti Whisperer, Silverado Goldfinger, Un...
# 14       Sports                          Satisfaction Confidential
# 15       Travel                            Desperate Trainspotting
#
#     title_length
# 0             23
# 1             22
# 2             20
# 3             23
# 4             23
# 5             22
# 6             22
# 7             22
# 8             20
# 9             21
# 10            27
# 11            22
# 12            21
# 13            20
# 14            25
# 15            23

# %% [markdown]
# ***11. Znajdź najdłuższy film we wszystkich kategoriach. Porównaj wynik z pkt 10.***

# %%
sql = f'''SELECT
              name, STRING_AGG(title, ', ') AS titles, length
          FROM (
              SELECT
                  f.name, f.title, f.length
              FROM (
                  SELECT
                      category.name, film.title, film.length
                  FROM
                      category
                  INNER JOIN film_category ON category.category_id=film_category.category_id
                  INNER JOIN film ON film_category.film_id=film.film_id) AS f
              INNER JOIN (
                  SELECT
                      category.name, MAX(film.length)
                  FROM
                      category
                  INNER JOIN film_category ON category.category_id=film_category.category_id
                  INNER JOIN film ON film_category.film_id=film.film_id
                  GROUP BY
                      category.name) AS c ON f.name=c.name AND f.length=c.max) AS _
          GROUP BY
              name, length;'''

pd.read_sql(sql, con=main.connection)
# Out:
#            name                            titles  length
# 0        Action      Darn Forrester, Worst Banger     185
# 1     Animation         Pond Seattle, Gangs Pride     185
# 2      Children       Fury Murder, Wrong Behavior     178
# 3      Classics                 Conspiracy Spirit     184
# 4        Comedy                    Control Anthem     185
# 5   Documentary         Young Language, Wife Turn     183
# 6         Drama                     Jacket Frisco     181
# 7        Family                    King Evolution     184
# 8       Foreign  Sorority Queen, Crystal Breaking     184
# 9         Games                     Chicago North     185
# 10       Horror   Analyze Hoosiers, Love Suicides     181
# 11        Music                         Home Pity     185
# 12          New                    Frontier Cabin     183
# 13       Sci-Fi                Soldiers Evolution     185
# 14       Sports                   Smoochy Control     184
# 15       Travel  Sweet Brotherhood, Muscle Bright     185

# %% [markdown]
# Długość filmu jest podawana w minutach.
# Porównanie wyników z zadaniem 10. jest niemożliwe - długość filmu nie zależy od długości tytułu.

# %% [markdown]
# ## Zadanie implementacyjne
# Zaimplementuj wszystkie funkcje w pliku main.py zgodnie z opisem a następnie przetestuj je w notatniku.

# %%
main.film_in_category(15)
# Out:
#                  title               languge category
# 0     Aladdin Calendar  English                Sports
# 1      Anonymous Human  English                Sports
# 2   Artist Coldblooded  English                Sports
# 3        Bubble Grosse  English                Sports
# 4     California Birds  English                Sports
# ..                 ...                   ...      ...
# 69         Tights Dawn  English                Sports
# 70     Tourist Pelican  English                Sports
# 71   Trading Pinocchio  English                Sports
# 72         Tuxedo Mile  English                Sports
# 73     Victory Academy  English                Sports
#
# [74 rows x 3 columns]

# %%
main.number_films_in_category(15)
# Out:
#   category  count
# 0   Sports     74

# %% [markdown]
# Liczba filmów w kategorii Sports się zgadza.

# %%
main.number_film_by_length(min_length=60, max_length=80.5)
# Out:
#     length  count
# 0       80     10
# 1       61     10
# 2       67      8
# 3       77      6
# 4       66      2
# 5       73     12
# 6       62      6
# 7       65      7
# 8       76      7
# 9       69      6
# 10      79      6
# 11      78      6
# 12      63      9
# 13      70      7
# 14      64      9
# 15      68      5
# 16      60      8
# 17      74     12
# 18      71      7
# 19      72      4
# 20      75     10

# %%
main.client_from_city("Aurora")
# Out:
#      city first_name last_name
# 0  Aurora    Clinton    Buford
# 1  Aurora      Scott   Shelley

# %%
main.avg_amount_by_length(80)
# Out:
#    length      avg
# 0      80  5.48359

# %%
main.client_by_sum_length(4308)
# Out:
#    first_name  last_name   sum
# 0         Sue     Peters  4319
# 1       Louis      Leone  4333
# 2      Angela  Hernandez  4362
# 3      Janice       Ward  4366
# 4       Daisy      Bates  4369
# 5         Tim       Cary  4476
# 6       Diane    Collins  4514
# 7   Elizabeth      Brown  4531
# 8      Justin        Ngo  4550
# 9      Sherry   Marshall  4582
# 10     Marion     Snyder  4599
# 11    Russell    Brinson  4640
# 12     Marcia       Dean  4734
# 13     Wesley       Bull  4808
# 14      Clara       Shaw  4808
# 15      Tammy    Sanders  5065
# 16    Eleanor       Hunt  5360
# 17       Karl       Seal  5388

# %%
main.category_statistic_length("Sports")
# Out:
#   category         avg   sum  min  max
# 0   Sports  128.202703  9487   47  184
